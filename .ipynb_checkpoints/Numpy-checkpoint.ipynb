# %% [markdown]
# ## Welcome to Numpy

# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5],dtype = 'i')    #list

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %%
b = np.array((2,4,6,8,10),dtype = 'f')   #tuple

# %%
print(b)
# Out:
# [ 2.  4.  6.  8. 10.]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.dtype
# Out:
# dtype('float32')

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.ndim
# Out:
# 1

# %%
c = np.array([[1,2,3],[4,5,6]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c.ndim
# Out:
# 2

# %%
c[0,2]
# Out:
# np.int64(3)

# %%
a[0]
# Out:
# np.int32(1)
